# %%
import pandas as pd

# %%
df = pd.read_csv('Covid19Casos.csv')

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    id_evento_caso sexo  edad edad_años_meses residencia_pais_nombre  \
# 0         1000000    M  53.0            Años              Argentina
# 1         1000002    M  21.0            Años              Argentina
# 2         1000003    F  40.0            Años              Argentina
# 3         1000005    F  58.0            Años              Argentina
# 4         1000006    M  28.0            Años              Argentina
#
#   residencia_provincia_nombre residencia_departamento_nombre  \
# 0                        CABA                SIN ESPECIFICAR
# 1                Buenos Aires                     La Matanza
# 2                     Córdoba                        Capital
# 3                     Mendoza                      Las Heras
# 4                Buenos Aires            Malvinas Argentinas
#
#   carga_provincia_nombre fecha_inicio_sintomas fecha_apertura  ...  \
# 0           Buenos Aires                   NaN     2020-06-01  ...
# ...

# %%
df.tail()
# Out:
#          id_evento_caso sexo  edad edad_años_meses residencia_pais_nombre  \
# 2713010          999994    M  39.0            Años              Argentina
# 2713011          999995    M  34.0            Años              Argentina
# 2713012          999996    M  42.0            Años              Argentina
# 2713013          999997    F  30.0            Años              Argentina
# 2713014          999999    F  57.0            Años              Argentina
#
#         residencia_provincia_nombre residencia_departamento_nombre  \
# 2713010            Tierra del Fuego                     Río Grande
# 2713011                     Formosa                      Pilcomayo
# 2713012                        CABA                SIN ESPECIFICAR
# 2713013                        CABA                SIN ESPECIFICAR
# 2713014                Buenos Aires             General San Martín
#
#         carga_provincia_nombre fecha_inicio_sintomas fecha_apertura  ...  \
# ...

# %%
df.sample(5)
# Out:
#          id_evento_caso sexo  edad edad_años_meses residencia_pais_nombre  \
# 2425032         3678794    F  40.0            Años              Argentina
# 1506112         2697147    M  28.0            Años              Argentina
# 1280965         2454404    F  28.0            Años              Argentina
# 1342331         2520882    M  45.0            Años        SIN ESPECIFICAR
# 2521884         3782107    F  45.0            Años              Argentina
#
#         residencia_provincia_nombre residencia_departamento_nombre  \
# 2425032                     Neuquén                    Confluencia
# 1506112                        CABA                SIN ESPECIFICAR
# 1280965                     Mendoza                        Capital
# 1342331                  Entre Ríos                      Villaguay
# 2521884                Buenos Aires                   San Cayetano
#
#         carga_provincia_nombre fecha_inicio_sintomas fecha_apertura  ...  \
# ...

# %%
df.shape
# Out:
# (2713015, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2713015 entries, 0 to 2713014
# Data columns (total 25 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   id_evento_caso                    int64
#  1   sexo                              object
#  2   edad                              float64
#  3   edad_años_meses                   object
#  4   residencia_pais_nombre            object
#  5   residencia_provincia_nombre       object
#  6   residencia_departamento_nombre    object
#  7   carga_provincia_nombre            object
#  8   fecha_inicio_sintomas             object
#  9   fecha_apertura                    object
#  10  sepi_apertura                     int64
#  11  fecha_internacion                 object
#  12  cuidado_intensivo                 object
#  13  fecha_cui_intensivo               object
#  14  fallecido                         object
#  15  fecha_fallecimiento               object
# ...

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html

# %%
df.describe()
# Out:
#        id_evento_caso          edad  sepi_apertura  carga_provincia_id  \
# count    1.037453e+06  1.036164e+06   1.037453e+06        1.037453e+06
# mean     1.429494e+06  3.938215e+01   2.832439e+01        1.443695e+01
# std      3.505180e+05  1.965566e+01   4.943110e+00        2.295405e+01
# min      6.720640e+05  0.000000e+00   5.000000e+00        2.000000e+00
# 25%      1.134679e+06  2.700000e+01   2.600000e+01        2.000000e+00
# 50%      1.434423e+06  3.700000e+01   3.000000e+01        6.000000e+00
# 75%      1.731584e+06  5.100000e+01   3.200000e+01        6.000000e+00
# max      2.026429e+06  1.300000e+02   4.400000e+01        9.400000e+01
#
#        residencia_provincia_id  residencia_departamento_id
# count             1.037453e+06                1.037453e+06
# mean              1.529723e+01                2.633905e+02
# std               2.333969e+01                2.716996e+02
# min               2.000000e+00                0.000000e+00
# ...

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html

# %%
df.describe(include=['object'])
# Out:
#            sexo edad_años_meses residencia_pais_nombre  \
# count   2713015         2713015                2713015
# unique        3               2                     32
# top           F            Años              Argentina
# freq    1379927         2694587                2602582
#
#        residencia_provincia_nombre residencia_departamento_nombre  \
# count                      2713015                        2713015
# unique                          25                            446
# top                   Buenos Aires                SIN ESPECIFICAR
# freq                       1271082                         289586
#
#        carga_provincia_nombre fecha_inicio_sintomas fecha_apertura  \
# count                 2713015               1438632        2713014
# unique                     24                   298            248
# top              Buenos Aires            2020-09-01     2020-10-22
# freq                  1015668                 15025          36796
#
# ...

# %%
df.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 2713010    False
# 2713011    False
# 2713012    False
# 2713013    False
# 2713014    False
# Length: 2713015, dtype: bool

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['id_evento_caso', 'sexo', 'edad', 'edad_años_meses',
#        'residencia_pais_nombre', 'residencia_provincia_nombre',
#        'residencia_departamento_nombre', 'carga_provincia_nombre',
#        'fecha_inicio_sintomas', 'fecha_apertura', 'sepi_apertura',
#        'fecha_internacion', 'cuidado_intensivo', 'fecha_cui_intensivo',
#        'fallecido', 'fecha_fallecimiento', 'asistencia_respiratoria_mecanica',
#        'carga_provincia_id', 'origen_financiamiento', 'clasificacion',
#        'clasificacion_resumen', 'residencia_provincia_id', 'fecha_diagnostico',
#        'residencia_departamento_id', 'ultima_actualizacion'],
#       dtype='object')

# %%
df.duplicated(subset=['sexo','edad'])
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 2713010     True
# 2713011     True
# 2713012     True
# 2713013     True
# 2713014     True
# Length: 2713015, dtype: bool

# %%
df.duplicated(subset=['sexo','edad']).sum()
# Out:
# 2712672

# %%
df['residencia_pais_nombre'].value_counts()
# Out:
# Argentina               2602582
# SIN ESPECIFICAR          109987
# Paraguay                    115
# Bolivia                      97
# Chile                        53
# Brasil                       51
# Uruguay                      34
# Italia                       14
# Perú                         12
# España                        9
# Alemania                      9
# Francia                       8
# Venezuela                     8
# China                         5
# Reino Unido                   4
# EE.UU.                        3
# Australia                     3
# Colombia                      3
# Filipinas                     2
# Ecuador                       2
# Austria                       2
# Malasia                       2
# Polonia                       1
# Ucrania                       1
# Portugal                      1
# Líbano                        1
# Países Bajos                  1
# Canadá                        1
# Panamá                        1
# ...

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html

# %%
df['fecha_inicio_sintomas'].value_counts(dropna=False)
# Out:
# NaN           426961
# 2020-08-10     11443
# 2020-08-01     11336
# 2020-08-03     11086
# 2020-07-20     10411
#                ...
# 2020-01-16         1
# 2020-01-13         1
# 2020-01-08         1
# 2020-01-06         1
# 2020-01-03         1
# Name: fecha_inicio_sintomas, Length: 225, dtype: int64

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['id_evento_caso', 'sexo', 'edad', 'edad_años_meses',
#        'residencia_pais_nombre', 'residencia_provincia_nombre',
#        'residencia_departamento_nombre', 'carga_provincia_nombre',
#        'fecha_inicio_sintomas', 'fecha_apertura', 'sepi_apertura',
#        'fecha_internacion', 'cuidado_intensivo', 'fecha_cui_intensivo',
#        'fallecido', 'fecha_fallecimiento', 'asistencia_respiratoria_mecanica',
#        'carga_provincia_id', 'origen_financiamiento', 'clasificacion',
#        'clasificacion_resumen', 'residencia_provincia_id', 'fecha_diagnostico',
#        'residencia_departamento_id', 'ultima_actualizacion'],
#       dtype='object')

# %%
df.fallecido
# Out:
# 0          NO
# 1          NO
# 2          NO
# 3          NO
# 4          NO
#            ..
# 2713010    NO
# 2713011    NO
# 2713012    NO
# 2713013    NO
# 2713014    NO
# Name: fallecido, Length: 2713015, dtype: object

# %%
df.sexo.unique()
# Out:
# array(['M', 'F', 'NR'], dtype=object)

# %%
df[df.sexo=='M']
# Out:
#          id_evento_caso sexo  edad edad_años_meses residencia_pais_nombre  \
# 0               1000000    M  53.0            Años              Argentina
# 1               1000002    M  21.0            Años              Argentina
# 4               1000006    M  28.0            Años              Argentina
# 5               1000007    M  26.0            Años              Argentina
# 7               1000009    M  73.0            Años              Argentina
# ...                 ...  ...   ...             ...                    ...
# 2713005          999988    M  37.0            Años              Argentina
# 2713006          999989    M  50.0            Años              Argentina
# 2713010          999994    M  39.0            Años              Argentina
# 2713011          999995    M  34.0            Años              Argentina
# 2713012          999996    M  42.0            Años              Argentina
#
#         residencia_provincia_nombre residencia_departamento_nombre  \
# ...

# %%
df[df.sexo=='F']
# Out:
#          id_evento_caso sexo  edad edad_años_meses residencia_pais_nombre  \
# 2               1000003    F  40.0            Años              Argentina
# 3               1000005    F  58.0            Años              Argentina
# 6               1000008    F  69.0            Años              Argentina
# 11              1000013    F  43.0            Años              Argentina
# 13              1000015    F  29.0            Años              Argentina
# ...                 ...  ...   ...             ...                    ...
# 2713007          999990    F  50.0            Años              Argentina
# 2713008          999992    F  28.0            Años              Argentina
# 2713009          999993    F  37.0            Años              Argentina
# 2713013          999997    F  30.0            Años              Argentina
# 2713014          999999    F  57.0            Años              Argentina
#
#         residencia_provincia_nombre residencia_departamento_nombre  \
# ...

# %%
df[df.sexo=='NR']
# Out:
#          id_evento_caso sexo  edad edad_años_meses residencia_pais_nombre  \
# 62              1000085   NR  35.0            Años              Argentina
# 251             1000364   NR   NaN            Años              Argentina
# 858             1001152   NR  43.0            Años              Argentina
# 937             1001262   NR  31.0            Años              Argentina
# 1409            1001862   NR   6.0           Meses              Argentina
# ...                 ...  ...   ...             ...                    ...
# 2711859          998372   NR   NaN            Años              Argentina
# 2712178          998832   NR  40.0            Años              Argentina
# 2712596          999427   NR   NaN            Años              Argentina
# 2712638          999494   NR   NaN            Años               Paraguay
# 2712981          999955   NR   5.0           Meses              Argentina
#
#         residencia_provincia_nombre residencia_departamento_nombre  \
# ...

# %%
df[df.sexo=='F'].fallecido
# Out:
# 2          NO
# 3          NO
# 6          NO
# 11         NO
# 13         NO
#            ..
# 2713007    NO
# 2713008    NO
# 2713009    NO
# 2713013    NO
# 2713014    NO
# Name: fallecido, Length: 1379927, dtype: object

# %%
df[df.sexo=='M'].fallecido
# Out:
# 0          NO
# 1          NO
# 4          NO
# 5          NO
# 7          NO
#            ..
# 2713005    NO
# 2713006    NO
# 2713010    NO
# 2713011    NO
# 2713012    NO
# Name: fallecido, Length: 1324304, dtype: object

# %%
df[df.sexo=='NR'].fallecido
# Out:
# 62         NO
# 251        NO
# 858        NO
# 937        NO
# 1409       NO
#            ..
# 2711859    NO
# 2712178    NO
# 2712596    NO
# 2712638    NO
# 2712981    NO
# Name: fallecido, Length: 8784, dtype: object

# %%
fallecidas=(df[df.sexo=='F'].fallecido=='SI').sum()
fallecidas
# Out:
# 15855

# %%
fallecidos=(df[df.sexo=='M'].fallecido=='SI').sum()
fallecidos
# Out:
# 20394

# %%
fallecidxs=(df[df.sexo=='NR'].fallecido=='SI').sum()
fallecidxs
# Out:
# 237

# %%
plt.ylabel('Fallecimientos')
plt.xlabel('Sexo')
plt.title('Fallecimientos por sexo')
plt.bar(['F', 'M', 'NR'], [fallecidas, fallecidos, fallecidxs])
plt.show()

# %% [markdown]
# ## Reciben asistencia mecanica y mueren

# %%
df.asistencia_respiratoria_mecanica.unique()
# Out:
# array(['NO', 'SI'], dtype=object)

# %%
df[df.asistencia_respiratoria_mecanica=='SI']
# Out:
#          id_evento_caso sexo  edad edad_años_meses residencia_pais_nombre  \
# 117             1000163    M  59.0            Años              Argentina
# 261             1000382    F  82.0            Años              Argentina
# 365             1000514    M  62.0            Años              Argentina
# 433             1000606    M  56.0            Años              Argentina
# 441             1000618    F  31.0            Años              Argentina
# ...                 ...  ...   ...             ...                    ...
# 2712771          999675    M  23.0            Años              Argentina
# 2712827          999758    F  86.0            Años              Argentina
# 2712850          999793    F  76.0            Años              Argentina
# 2712853          999796    F  46.0            Años              Argentina
# 2712932          999898    M  14.0            Años              Argentina
#
#         residencia_provincia_nombre residencia_departamento_nombre  \
# ...

# %%
import seaborn as sns

UTI_muertes = df[df.asistencia_respiratoria_mecanica=='SI']

sns.countplot(x="fallecido", data=UTI_muertes)

# %%
df.columns
# Out:
# Index(['id_evento_caso', 'sexo', 'edad', 'edad_años_meses',
#        'residencia_pais_nombre', 'residencia_provincia_nombre',
#        'residencia_departamento_nombre', 'carga_provincia_nombre',
#        'fecha_inicio_sintomas', 'fecha_apertura', 'sepi_apertura',
#        'fecha_internacion', 'cuidado_intensivo', 'fecha_cui_intensivo',
#        'fallecido', 'fecha_fallecimiento', 'asistencia_respiratoria_mecanica',
#        'carga_provincia_id', 'origen_financiamiento', 'clasificacion',
#        'clasificacion_resumen', 'residencia_provincia_id', 'fecha_diagnostico',
#        'residencia_departamento_id', 'ultima_actualizacion'],
#       dtype='object')

# %%
df.fallecido
# Out:
# 0          NO
# 1          NO
# 2          NO
# 3          NO
# 4          NO
#            ..
# 2713010    NO
# 2713011    NO
# 2713012    NO
# 2713013    NO
# 2713014    NO
# Name: fallecido, Length: 2713015, dtype: object

# %%
import seaborn as sns

tips= df[df.fallecido=='SI']

sns.boxplot(x=tips["edad"])

# %%
import seaborn as sns

sns.set_theme(style="whitegrid")

tips = sns.load_dataset("tips")

ax = sns.boxplot(x=tips["total_bill"])
